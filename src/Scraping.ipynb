# %%
from selenium import webdriver
from pandas import *
import pandas
import json

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36"')

# %%
path_to_chromedriver = '/usr/local/bin/chromedriver' # Path to access a chrome driver
browser = webdriver.Chrome(executable_path=path_to_chromedriver, options=chrome_options)

# %%
url = 'https://stats.nba.com/team/1610612744/boxscores-traditional/'
browser.get(url)

# %%
table = browser.find_element_by_class_name('nba-stat-table__overflow')

# %%
team_date = []
team_win = []
team_stats = []
column_names = []

for line_id, lines in enumerate(table.text.split('\n')):
    if line_id == 0:
        column_names = lines.split(' ')[1:]
    else:
        temp = []
        parse = lines.split()
        team_date.append(parse[0] + " " + parse[1] + " " + parse[2] + " " + parse[3] + " " + parse[4] + " " + parse[5] + " " + parse[6])
        team_win.append(parse[7])
        for i in range(8,28):
            temp.append(float(parse[i]))
        team_stats.append(temp)

# %%
# Next Page
browser.find_element_by_xpath('/html/body/main/div[2]/div/div/div[3]/div/div/div/nba-stat-table/div[3]/div/div/a[2]').click()

# %%
table = browser.find_element_by_class_name('nba-stat-table__overflow')

# %%
for line_id, lines in enumerate(table.text.split('\n')):
    if line_id == 0:
        column_names = lines.split(' ')[1:]
    else:
        temp = []
        parse = lines.split()
        team_date.append(parse[0] + " " + parse[1] + " " + parse[2] + " " + parse[3] + " " + parse[4] + " " + parse[5] + " " + parse[6])
        team_win.append(parse[7])
        for i in range(8,28):
            temp.append(float(parse[i]))
        team_stats.append(temp)

# %%
db = pandas.DataFrame({'MATCH UP': team_date,
                       'W/L': team_win,
                       'MIN': [i[0] for i in team_stats],
                       'PTS': [i[1] for i in team_stats],
                       'FGM': [i[2] for i in team_stats], 
                       'FGA': [i[3] for i in team_stats],
                       'FG%': [i[4] for i in team_stats],
                       '3PM': [i[5] for i in team_stats],
                       '3PA': [i[6] for i in team_stats],
                       '3P%': [i[7] for i in team_stats],
                       'FTM': [i[8] for i in team_stats],
                       'FTA': [i[9] for i in team_stats],
                       'FT%': [i[10] for i in team_stats],
                       'OREB': [i[11] for i in team_stats],
                       'DREB': [i[12] for i in team_stats],
                       'REB': [i[13] for i in team_stats],
                       'AST': [i[14] for i in team_stats],
                       'TOV': [i[15] for i in team_stats],
                       'STL': [i[16] for i in team_stats],
                       'BLK': [i[17] for i in team_stats],
                       'PF': [i[18] for i in team_stats],
                       '+/-': [i[19] for i in team_stats],
                       }
                     )

# %%
db
# Out:
#                       MATCH UP W/L   MIN    PTS   FGM    FGA   FG%   3PM  \
# 0     Apr 10, 2019 - GSW @ MEM   L  48.0  117.0  46.0   92.0  50.0  13.0
# 1     Apr 09, 2019 - GSW @ NOP   W  48.0  112.0  43.0   89.0  48.3  12.0
# 2   Apr 07, 2019 - GSW vs. LAC   W  48.0  131.0  53.0   97.0  54.6  12.0
# 3   Apr 05, 2019 - GSW vs. CLE   W  48.0  120.0  46.0   87.0  52.9  20.0
# 4     Apr 04, 2019 - GSW @ LAL   W  48.0  108.0  43.0   98.0  43.9  18.0
# 5   Apr 02, 2019 - GSW vs. DEN   W  48.0  116.0  50.0   92.0  54.3  13.0
# 6   Mar 31, 2019 - GSW vs. CHA   W  48.0  137.0  53.0   88.0  60.2  21.0
# 7     Mar 29, 2019 - GSW @ MIN   L  53.0  130.0  46.0   98.0  46.9  18.0
# 63  29.0  24.1  ...   66.7   7.0  35.0  42.0  24.0  17.0   7.0  10.0  18.0
# 64  26.0  19.2  ...   81.0  10.0  36.0  46.0  20.0  12.0   6.0   4.0  17.0
# 65  33.0  27.3  ...   94.1  12.0  35.0  47.0  24.0  12.0   6.0   6.0  27.0
# 66  18.0  22.2  ...   81.8  12.0  32.0  44.0  18.0  17.0   2.0   5.0  24.0
# 67  27.0  44.4  ...   95.2  13.0  35.0  48.0  28.0  13.0   8.0   6.0  20.0
# 68  31.0  38.7  ...   69.6  11.0  35.0  46.0  27.0  17.0   7.0   8.0  25.0
# 69  16.0  43.8  ...   81.0   6.0  30.0  36.0  27.0  10.0   9.0   7.0  24.0
# 70  28.0  35.7  ...   77.3   8.0  30.0  38.0  31.0  18.0   5.0   6.0  22.0
# 71  24.0  54.2  ...   95.7   8.0  38.0  46.0  29.0  13.0   4.0   4.0  25.0
# 72  34.0  38.2  ...   77.3  12.0  49.0  61.0  31.0  16.0   3.0   9.0  16.0
# 73  32.0  50.0  ...   70.0  12.0  34.0  46.0  39.0  17.0  10.0   4.0  24.0
# 74  45.0  53.3  ...   73.1   8.0  41.0  49.0  34.0   7.0   9.0   7.0  29.0
# 75  33.0  33.3  ...   87.5  12.0  35.0  47.0  28.0  12.0  11.0   7.0  16.0
# 76  33.0  48.5  ...   83.3   6.0  33.0  39.0  26.0  14.0  10.0   6.0  16.0
# 77  33.0  45.5  ...   92.0  10.0  38.0  48.0  37.0  18.0   6.0   5.0  22.0
# 78  37.0  37.8  ...   73.1   7.0  33.0  40.0  35.0  14.0  12.0   4.0  24.0
# 79  29.0  24.1  ...   79.2   6.0  34.0  40.0  22.0  19.0   4.0   6.0  29.0
# 80  19.0  52.6  ...   88.9   8.0  35.0  43.0  27.0  16.0  10.0   6.0  23.0
# 81  26.0  26.9  ...   94.4  17.0  41.0  58.0  28.0  21.0   7.0   7.0  29.0
#
#      +/-
# 0  -15.0
# 1    9.0
# 2   27.0
# 3    6.0
# 4   18.0
# 5   14.0
# 6   47.0
# 7   -1.0
# 8   15.0
# 9    7.0
# 10 -35.0
# 11  23.0
# 12  10.0
# 13  -6.0
# 14  22.0
# 15   2.0
# 16  -4.0
# 17  17.0
# 18 -33.0
# 19   3.0
# 20  -7.0
# 21  -1.0
# 22  11.0
# 23  -6.0
# 24   2.0
# 25 -22.0
# 26   7.0
# 27   2.0
# 28  10.0
# 29  39.0
# ..   ...
# 52   5.0
# 53 -20.0
# 54   8.0
# 55  10.0
# 56  24.0
# 57  17.0
# 58  -9.0
# 59  -3.0
# 60   6.0
# 61   1.0
# 62  28.0
# 63 -28.0
# 64 -12.0
# 65  -3.0
# 66 -21.0
# 67   7.0
# 68  -5.0
# 69  16.0
# 70 -23.0
# 71  16.0
# 72  17.0
# 73  10.0
# 74  25.0
# 75   6.0
# 76  28.0
# 77  22.0
# 78  20.0
# 79  -2.0
# 80   1.0
# 81   8.0
#
# [82 rows x 22 columns]

# %%
# Set to Export Location
db.to_json(r'/Users/kevin/Documents/Sublime/SeleksiBasdat/data.json', orient='records', lines = True)

# %%
browser.close()

# %%
print('Export data to JSON file as "data.json" success')
# Out:
# Export data to JSON file as "data.json" success
